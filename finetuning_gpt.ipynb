# %% [markdown]
# <a href="https://colab.research.google.com/github/sevenweeks-07/GPT-2-Finetuning/blob/main/finetuning_gpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git config --global user.email "saatvikprabhu07x@gmail.com"
# !git config --global user.name "sevenweeks-07"

# %%
# !git clone https://github.com/sevenweeks-07/GPT-2-Finetuning.git
# Out:
# Cloning into 'GPT-2-Finetuning'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !cp /content/finetuning_gpt.ipynb /content/repository/
# Out:
# cp: cannot stat '/content/finetuning_gpt.ipynb': No such file or directory

# %%
# !ls /content/
# Out:
# GPT-2-Finetuning  sample_data
